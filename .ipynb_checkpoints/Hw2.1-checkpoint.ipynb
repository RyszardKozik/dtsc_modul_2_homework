# %%
import pandas as pd 
import numpy as np

url = "https://en.wikipedia.org/wiki/Demographics_of_Ukraine"

# Read all tables from the URL
tables = pd.read_html(url)

for i, table in enumerate(tables):
    print(f"Table {i}")
    print(table.head(), "\n")
# Out:
# Table 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please help ...
# 2 NaN  This article needs additional citations for ve...
#
# Table 1
#     0                                                  1
# 0 NaN  This article needs to be updated. Please help ...
#
# Table 2
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
#
# Table 3
#                           Demographics of Ukraine  \
# 0  Ukraine population pyramid on 31 December 2023
# 1                                      Population
# 2                                     Growth rate
# 3                                      Birth rate
# 4                                      Death rate
#
#                            Demographics of Ukraine.1
# 0     Ukraine population pyramid on 31 December 2023
# 1  Including Russian occupied territory: 41,130,4...
# 2                −6.6 people/1,000 population (2023)
# 3                 8.6 births/1,000 population (2023)
# 4                15.2 deaths/1,000 population (2023)
#
# Table 4
#     0                                                  1
# 0 NaN  Graphs are unavailable due to technical issues...
#
# Table 5
#     0                                                  1
# 0 NaN  Graphs are unavailable due to technical issues...
#
# Table 6
#       Period  Life expectancy in Years
# 0  1950–1955                     61.83
# 1  1955–1960                     67.11
# 2  1960–1965                     69.69
# 3  1965–1970                     70.66
# 4  1970–1975                     70.57
#
# Table 7
#    Unnamed: 0  Average population  Live births  Deaths  Natural change  \
# 0        1900            24969000      1203334  660723          542611
# 1        1901            25505000      1123519  657883          465636
# 2        1902            25935000      1207512  681580          525932
# 3        1903            26449000      1188404  663067          525337
# 4        1904            26961000      1228116  682068          546048
#
#    Crude birth rate (per 1,000)  Crude death rate (per 1,000)  \
# 0                          48.2                          26.5
# 1                          44.1                          25.8
# 2                          46.6                          26.3
# 3                          44.9                          25.1
# 4                          45.6                          25.3
#
#    Natural change (per 1,000)  Total fertility rates
# 0                        21.7                    NaN
# 1                        18.3                    NaN
# 2                        20.3                    NaN
# 3                        19.9                    NaN
# 4                        20.3                    NaN
#
# Table 8
#    [42]  Average population  Live births    Deaths  Natural change  \
# 0  1924            27400000      1211000  484880.0        726120.0
# 1  1925            28000000      1246000  531819.0        714181.0
# 2  1926            28700000      1258000  518656.0        739344.0
# 3  1927            29589000      1228000  579000.0        649000.0
# 4  1928            30251000      1178000  575000.0        603000.0
#
#    Crude birth rate (per 1,000)  Crude death rate (per 1,000)  \
# 0                          43.3                          17.3
# 1                          43.4                          18.5
# 2                          42.5                          17.5
# 3                          40.6                          19.1
# 4                          38.1                          18.6
#
#    Natural change (per 1,000)  Fertility rates  Life Expectancy (male)  \
# 0                        25.9              NaN                     NaN
# 1                        24.9             5.39                     NaN
# 2                        25.0              NaN                     NaN
# 3                        21.5              NaN                    43.3
# 4                        19.5              NaN                    44.6
#
#    Life Expectancy (female)
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                      46.8
# 4                      48.7
#
# Table 9
#   Unnamed: 0 Average population  Live births  Deaths  Natural change  \
# 0       1945                NaN     435230.0     NaN             NaN
# 1       1946                NaN     753493.0     NaN             NaN
# 2       1947                NaN     712994.0     NaN             NaN
# 3       1948                NaN     757783.0     NaN             NaN
# 4       1949                NaN     911641.0     NaN             NaN
#
#    Crude birth rate (per 1,000)  Crude death rate (per 1,000)  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Natural change (per 1,000)  Fertility rates  Urban fertility  \
# 0                         NaN              NaN              NaN
# 1                         NaN              NaN              NaN
# 2                         NaN              NaN              NaN
# 3                         NaN              NaN              NaN
# 4                         NaN              NaN              NaN
#
#    Rural fertility  Abortions, reported
# 0              NaN                  NaN
# 1              NaN                  NaN
# 2              NaN                  NaN
# 3              NaN                  NaN
# 4              NaN                  NaN
#
# Table 10
#    Unnamed: 0  Urban live births  Urban deaths Urban natural change  \
# 0        1990             442869        357114                85755
# 1        1991             419205        380988                38217
# 2        1992             387696        401849              −14,153
# 3        1993             356833        432462              −75,629
# 4        1994             328522        450823             −122,301
#
#    Urban crude birth rate (per 1,000)  Urban crude death rate (per 1,000)  \
# 0                                12.7                                10.2
# 1                                11.9                                10.8
# 2                                11.0                                11.4
# 3                                10.1                                12.2
# 4                                 9.3                                12.8
#
#   Urban natural change (per 1,000)  Rural live births  Rural deaths  \
# 0                              2.5             214333        272488
# 1                              1.1             211608        288972
# 2                             −0.4             209089        295261
# 3                             −2.1             200634        309200
# 4                             −3.5             193023        313846
#
#   Rural natural change  Rural crude birth rate (per 1,000)  \
# 0              −58,155                                12.7
# 1              −77,364                                12.6
# 2              −86,172                                12.5
# 3             −108,566                                12.0
# 4             −120,823                                11.6
#
#    Rural crude death rate (per 1,000) Rural natural change (per 1,000)
# 0                                16.1                             −3.4
# 1                                17.2                             −4.6
# 2                                17.6                             −5.1
# 3                                18.5                             −6.5
# 4                                18.8                             −7.2
#
# Table 11
#               Period    Live births         Deaths  Natural increase
# 0  January-June 2023          96755         258055           -161300
# 1  January-June 2024          87600         250972           -163372
# 2         Difference  −9,155(-9.4%)  -7,083(-2.7%)             -2072
#
# Table 12
#   Age Group        Male      Female       Total     %
# 0     Total  19 195 376  22 223 341  41 418 717   100
# 1       0–4     871 807     817 549   1 689 356  4.08
# 2       5–9   1 184 223   1 113 485   2 297 708  5.55
# 3     10–14   1 179 905   1 112 800   2 292 705  5.54
# 4     15–19     978 279     923 149   1 901 428  4.59
#
# Table 13
#           Name of Oblast  Population as of Dec 2021
# 0         Donetsk Oblast                    4062839
# 1  Dnipropetrovsk Oblast                    3100320
# 2              Kyiv City                    2952577
# 3         Kharkiv Oblast                    2602207
# 4            Lviv Oblast                    2480137
#
# Table 14
#   Number of births by oblast for January–November  Birth/2016  Birth/2015  \
# 0                                       Kyiv City       33416       32382
# 1                           Dnipropetrovsk Oblast       28473       30620
# 2                                     Lviv Oblast       25708       25007
# 3                                    Odesa Oblast       24246       25182
# 4                                  Kharkiv Oblast       21992       22864
#
#    Death/2016  Death/2015
# 0       27772       27767
# 1       47934       49258
# 2       29247       30010
# 3       30479       31512
# 4       38502       38965
#
# Table 15
#   Number of births by oblast  Birth/2014  Birth/2013  Birth/2012  Birth/2011  \
# 0      Dnipropetrovsk Oblast       36497       36134       37087       36116
# 1             Donetsk Oblast       35595       41034       42839       41720
# 2                  Kyiv City       34821       33305       33887       32068
# 3                Lviv Oblast       30270       29542       30220       28904
# 4               Odesa Oblast       29465       29075       30384       29225
#
#    Death/2014  Death/2013  Death/2012  Death/2011
# 0       52722       51134       51486       52106
# 1       71799       69345       70496       71042
# 2       29992       28003       27840       27050
# 3       32450       31666       31667       31162
# 4       34155       33523       33648       33688
#
# Table 16
#   Birth rate by oblast  Birth/2014  Birth/2013  Birth/2012  Birth/2011  \
# 0         Rivne Oblast        14.8        15.1        15.9        15.3
# 1   Zakarpattia Oblast        14.6        14.7        15.1        14.8
# 2         Volyn Oblast        14.1        14.1        14.8        14.1
# 3    Chernivtsi Oblast        12.9        12.6        12.8        12.5
# 4         Odesa Oblast        12.3        12.1        12.7        12.2
#
#    Death/2014  Death/2013  Death/2012  Death/2011
# 0        12.7        12.6        12.4        12.3
# 1        11.8        11.8        11.8        11.7
# 2        13.2        13.1        13.2        13.3
# 3        12.8        12.7        12.5        12.4
# 4        14.3        14.0        14.1        14.1
#
# Table 17
#   Infant mortality by oblast  Death/2012  Death/2011  Death/2010  Death/2009
# 0             Donetsk Oblast         540         473         497         533
# 1      Dnipropetrovsk Oblast         370         343         347         329
# 2               Odesa Oblast         267         268         263         280
# 3                  Kyiv City         262         255         233         244
# 4                Lviv Oblast         233         272         266         238
#
# Table 18
#   Infant mortality per 1,000 by Oblast  Death/2012  Death/2011  Death/2010  \
# 0                       Donetsk Oblast        12.7        11.4        12.0
# 1                Dnipropetrovsk Oblast        10.0         9.5         9.7
# 2                      Cherkasy Oblast         9.6         8.1        10.0
# 3                    Kirovohrad Oblast         9.4        13.2        10.6
# 4                     Chernihiv Oblast         9.2         7.9         8.1
#
#    Death/2009
# 0        12.3
# 1         8.8
# 2        10.5
# 3        10.9
# 4         9.9
#
# Table 19
#   Children born per woman by oblast  Total fertility rate/2020  \
# 0                      Rivne Oblast                       1.54
# 1                Zakarpattia Oblast                       1.60
# 2                      Volyn Oblast                       1.51
# 3                   Zhytomyr Oblast                       1.20
# 4                      Odesa Oblast                       1.34
#
#    Total fertility rate/2012  Total fertility rate/2011  \
# 0                       2.08                       1.99
# 1                       1.95                       1.90
# 2                       1.92                       1.81
# 3                       1.71                       1.65
# 4                       1.71                       1.62
#
#    Total fertility rate/2010
# 0                       1.93
# 1                       1.83
# 2                       1.85
# 3                       1.61
# 4                       1.58
#
# Table 20
#   Birth rate in regional centers  Birth/2012  Birth/2011  Birth/2010  \
# 0                     Simferopol        13.6        12.8        11.8
# 1                          Lutsk        12.6        12.3        12.6
# 2                          Rivne        12.6        12.0        11.8
# 3                       Uzhhorod        12.1        11.9        12.0
# 4                           Kyiv        12.0        11.4        11.5
#
#    Birth/2009  Birth/2007  Birth/2005  Birth/2003
# 0        11.8        11.0         9.5         9.2
# 1        13.9        12.6        11.7        10.0
# 2        12.3        10.9        10.1         9.4
# 3        12.4        12.8        12.6        10.8
# 4        11.7        10.4         9.8         8.8
#
# Table 21
#   Death rate in regional centers  Death/2012  Death/2011  Death/2010  \
# 0                        Kherson        15.2        15.6        14.0
# 1                        Luhansk        14.2        14.3        13.6
# 2                     Simferopol        14.0        14.8        13.6
# 3                     Sevastopol        13.7        14.1        14.7
# 4                  Kropyvnytskyi        13.7        13.7        13.8
#
#    Death/2009  Death/2007  Death/2005  Death/2003
# 0        14.2        14.9        14.8        14.5
# 1        13.4        13.8        14.2        14.1
# 2        13.8        15.3        15.3        15.2
# 3        14.5        15.5        15.4        14.1
# 4        14.0        14.4        14.1        14.1
#
# Table 22
#   Ethnic group census 19261       census 19392
#   Ethnic group       Number     %       Number     %
# 0   Ukrainians     23218860  80.0     23667509  76.5
# 1     Russians      2677166   9.2      4175299  13.5
# 2       Jewish      1574428   5.4      1532776   5.0
# 3      Germans       393924   1.4       392458   1.3
# 4       Polish       476435   1.6       357710   1.2
#
# Table 23
#             Ethnic group census 19591       census 19702       census 19793  \
#             Ethnic group       Number     %       Number     %       Number
# 0             Ukrainians     32158493  76.8     35283857  74.9     36488951
# 1               Russians      7090813  16.9      9126331  19.4     10471602
# 2  Romanians / Moldovans       391753   1.1       378043   1.1       415371
# 3            Belarusians       290890   0.7       385847   0.8       406098
# 4         Crimean Tatars          193   0.0         3554   0.0         6636
#
#         census 19894       census 20015
#       %       Number     %       Number     %
# 0  73.6     37419053  72.7     37541693  77.5
# 1  21.1     11355582  22.1      8334141  17.2
# 2   1.1       459350   1.2       409608   1.1
# 3   0.8       440045   0.9       275763   0.6
# 4   0.0        46807   0.1       248193   0.5
#
# Table 24
#      Ethnic group  Population    Native Ukrainian  Russian   Other
# 0      Ukrainians    37541693  31970728         –  5544729   532.0
# 1        Russians     8334141   7993832    328152        –   402.0
# 2       Moldovans      258619    181124     27775    45607  1242.0
# 3     Belarusians      275763     54573     48202   172251     NaN
# 4  Crimean Tatars      248193    228373       184    15208    43.0
#
# Table 25
#            0   1        2   3                      4   5
# 0        NaN NaN      NaN NaN                    NaN NaN
# 1  Ukrainian NaN  Russian NaN  Romanian and Moldovan NaN
#
# Table 26
#                0   1          2   3          4   5
# 0            NaN NaN        NaN NaN        NaN NaN
# 1  Crimean Tatar NaN  Bulgarian NaN  Hungarian NaN
#
# Table 27
#                       0   1                       2   3  \
# 0                   NaN NaN                     NaN NaN
# 1  All population, 2012 NaN  Urban population, 2009 NaN
#
#                         4   5
# 0                     NaN NaN
# 1  Rural population, 2009 NaN
#
# Table 28
#                                  0   1                                2   3  \
# 0                              NaN NaN                              NaN NaN
# 1  The birth rate in Ukraine, 2003 NaN  The birth rate in Ukraine, 2010 NaN
#
#                                  4   5
# 0                              NaN NaN
# 1  The death rate in Ukraine, 2010 NaN
#
# Table 29
#                          0   1                         2   3  \
# 0                      NaN NaN                       NaN NaN
# 1  Urbanization rate, 2011 NaN  Population density, 2013 NaN
#
#                                               4
# 0                                           NaN
# 1  Median population of rural settlements, 2011
#
# Table 30
#          vteDemographics of Europe  \
# 0                 Sovereign states
# 1  States with limited recognition
# 2  Dependencies and other entities
# 3                   Other entities
#
#                          vteDemographics of Europe.1
# 0  Albania Andorra Armenia Austria Azerbaijan Bel...
# 1  Abkhazia Kosovo Northern Cyprus South Ossetia ...
# 2  Åland Faroe Islands Gibraltar Guernsey Isle of...
# 3                                     European Union
#
# Table 31
#                                  vteUkraine articles  \
# 0                                            History
# 1                                         Chronology
# 2                                           By topic
# 3                                          Geography
# 4  National parks Biosphere reserves Seven Natura...
#
#                                vteUkraine articles.1
# 0  Chronology Scythians Sarmatians Goths Early Sl...
# 1  Scythians Sarmatians Goths Early Slavs East Sl...
# 2                     Christianity Economic Military
# 3  National parks Biosphere reserves Seven Natura...
# 4  National parks Biosphere reserves Seven Natura...
#
# Table 32
#             0                                                  1
# 0  Chronology  Scythians Sarmatians Goths Early Slavs East Sl...
# 1    By topic                     Christianity Economic Military
#
# Table 33
#                                                    0  \
# 0  National parks Biosphere reserves Seven Natura...
#
#                                                    1
# 0  National parks Biosphere reserves Seven Natura...
#
# Table 34
#                                                    0  \
# 0  Administrative divisions Constitution Flag Pre...
#
#                                                    1
# 0  Administrative divisions Constitution Flag Pre...
#
# Table 35
#                                                    0  \
# 0  Hryvnia (currency) Banking Stock exchanges Ene...
#
#                                                    1
# 0  Hryvnia (currency) Banking Stock exchanges Ene...
#
# Table 36
#                                                    0  \
# 0  Education Corruption Gender inequality Health ...
# 1                                            Culture
# 2                                       Demographics
#
#                                                    1
# 0  Education Corruption Gender inequality Health ...
# 1  Animation Architecture Kievan Rus' Baroque Art...
# 2  Ukrainian people Rus' people Ruthenians Diaspo...

# %%
import pandas as pd 
import numpy as np

url = "https://en.wikipedia.org/wiki/Demographics_of_Ukraine"
table = pd.read_html(url)
df = table[3]

# Display the first few rows of the table to confirm it's the right one
print("First few row of the selected table:")
print(df.head)
# Out:
# First few row of the selected table:
# <bound method NDFrame.head of                            Demographics of Ukraine  \
# 0   Ukraine population pyramid on 31 December 2023
# 1                                       Population
# 2                                      Growth rate
# 3                                       Birth rate
# 4                                       Death rate
# 5                                  Life expectancy
# 6                                           • male
# 7                                         • female
# 8                                   Fertility rate
# 9                            Infant mortality rate
# 10                              Net migration rate
# 11                                   Age structure
# 12                                      0–14 years
# 13                                     15–64 years
# 14                                     65 and over
# 15                                       Sex ratio
# 16                                        At birth
# 17                                        Under 15
# 18                                     15–64 years
# 19                                     65 and over
# 20                                     Nationality
# 21                                     Nationality
# 22                                    Major ethnic
# 23                                    Minor ethnic
# 24                                        Language
# 25                                        Official
# 26                                          Spoken
#
#                             Demographics of Ukraine.1
# 0      Ukraine population pyramid on 31 December 2023
# 1   Including Russian occupied territory: 41,130,4...
# 2                 −6.6 people/1,000 population (2023)
# 3                  8.6 births/1,000 population (2023)
# 4                 15.2 deaths/1,000 population (2023)
# 5                               71.76 years (2018)[4]
# 6                                         66.69 years
# 7                                         76.72 years
# 8                     1.16 children born/woman (2023)
# 9                  7.0 deaths/1,000 infants (2019)[4]
# 10            −5.4 migrant(s)/1,000 population (2015)
# 11                                      Age structure
# 12                                              15.4%
# 13                                              68.4%
# 14                                       16.2% (2017)
# 15                                          Sex ratio
# 16                                1.06 male(s)/female
# 17                                1.06 male(s)/female
# 18                                0.92 male(s)/female
# 19                                0.51 male(s)/female
# 20                                        Nationality
# 21            noun: Ukrainian(s) adjective: Ukrainian
# 22                            Ukrainians (77.8%) 2001
# 23           Russians (17.3%) 2001, Other (4.9%) 2001
# 24                                           Language
# 25                                          Ukrainian
# 26                         Ukrainian, Russian, others  >

# %%
import pandas as pd 
import numpy as np 

print("\nNumber of rows and columns in the DataFrame:")
print(df.shape)
# Out:
# Number of rows and columns in the DataFrame:
# (27, 2)

# %%
# Replace "-" with NaN
df.replace("_", np.nan, inplace=True)

# Print the update DataFrame
print("\nUpdate DataFrame after replacing '_' with NaN:")
print(df)
# Out:
# Update DataFrame after replacing '_' with NaN:
#                            Demographics of Ukraine  \
# 0   Ukraine population pyramid on 31 December 2023
# 1                                       Population
# 2                                      Growth rate
# 3                                       Birth rate
# 4                                       Death rate
# 5                                  Life expectancy
# 6                                           • male
# 7                                         • female
# 8                                   Fertility rate
# 9                            Infant mortality rate
# 10                              Net migration rate
# 11                                   Age structure
# 12                                      0–14 years
# 13                                     15–64 years
# 14                                     65 and over
# 15                                       Sex ratio
# 16                                        At birth
# 17                                        Under 15
# 18                                     15–64 years
# 19                                     65 and over
# 20                                     Nationality
# 21                                     Nationality
# 22                                    Major ethnic
# 23                                    Minor ethnic
# 24                                        Language
# 25                                        Official
# 26                                          Spoken
#
#                             Demographics of Ukraine.1
# 0      Ukraine population pyramid on 31 December 2023
# 1   Including Russian occupied territory: 41,130,4...
# 2                 −6.6 people/1,000 population (2023)
# 3                  8.6 births/1,000 population (2023)
# 4                 15.2 deaths/1,000 population (2023)
# 5                               71.76 years (2018)[4]
# 6                                         66.69 years
# 7                                         76.72 years
# 8                     1.16 children born/woman (2023)
# 9                  7.0 deaths/1,000 infants (2019)[4]
# 10            −5.4 migrant(s)/1,000 population (2015)
# 11                                      Age structure
# 12                                              15.4%
# 13                                              68.4%
# 14                                       16.2% (2017)
# 15                                          Sex ratio
# 16                                1.06 male(s)/female
# 17                                1.06 male(s)/female
# 18                                0.92 male(s)/female
# 19                                0.51 male(s)/female
# 20                                        Nationality
# 21            noun: Ukrainian(s) adjective: Ukrainian
# 22                            Ukrainians (77.8%) 2001
# 23           Russians (17.3%) 2001, Other (4.9%) 2001
# 24                                           Language
# 25                                          Ukrainian
# 26                         Ukrainian, Russian, others

# %%
# Define and print the data types of all columns
print("\nData types of all columns:")
print(df.dtypes)
# Out:
# Data types of all columns:
# Demographics of Ukraine      object
# Demographics of Ukraine.1    object
# dtype: object

# %%
# Replace the value "_" in the table with NaN
df.replace("_", np.nan, inplace=True)
print("Replace '_' with NaN")

# Change the types on non-numeric to numeric. Assuming these are the ones with '_'
df = df.apply(pd.to_numeric, errors="ignore")
# Out:
# Replace '_' with NaN
# C:\Users\winge\AppData\Local\Temp\ipykernel_5340\265667084.py:6: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")

# %%
# Calculate the proportion of missing values in each column
missing_values_proportion = df.isnull().sum() / len(df)

print("Proportion of missing values in each column:\n", missing_values_proportion)
# Out:
# Proportion of missing values in each column:
#  Demographics of Ukraine      0.0
# Demographics of Ukraine.1    0.0
# dtype: float64

# %%
# Remove the last row from the DataFrame
df.drop(df.tail(1).index, inplace=True)

print("DataFrame after removing the last row:\n", df)
# Out:
# DataFrame after removing the last row:
#                             Demographics of Ukraine  \
# 0   Ukraine population pyramid on 31 December 2023
# 1                                       Population
# 2                                      Growth rate
# 3                                       Birth rate
# 4                                       Death rate
# 5                                  Life expectancy
# 6                                           • male
# 7                                         • female
# 8                                   Fertility rate
# 9                            Infant mortality rate
# 10                              Net migration rate
# 11                                   Age structure
# 12                                      0–14 years
# 13                                     15–64 years
# 14                                     65 and over
# 15                                       Sex ratio
# 16                                        At birth
# 17                                        Under 15
# 18                                     15–64 years
# 19                                     65 and over
# 20                                     Nationality
# 21                                     Nationality
# 22                                    Major ethnic
# 23                                    Minor ethnic
# 24                                        Language
# 25                                        Official
#
#                             Demographics of Ukraine.1
# 0      Ukraine population pyramid on 31 December 2023
# 1   Including Russian occupied territory: 41,130,4...
# 2                 −6.6 people/1,000 population (2023)
# 3                  8.6 births/1,000 population (2023)
# 4                 15.2 deaths/1,000 population (2023)
# 5                               71.76 years (2018)[4]
# 6                                         66.69 years
# 7                                         76.72 years
# 8                     1.16 children born/woman (2023)
# 9                  7.0 deaths/1,000 infants (2019)[4]
# 10            −5.4 migrant(s)/1,000 population (2015)
# 11                                      Age structure
# 12                                              15.4%
# 13                                              68.4%
# 14                                       16.2% (2017)
# 15                                          Sex ratio
# 16                                1.06 male(s)/female
# 17                                1.06 male(s)/female
# 18                                0.92 male(s)/female
# 19                                0.51 male(s)/female
# 20                                        Nationality
# 21            noun: Ukrainian(s) adjective: Ukrainian
# 22                            Ukrainians (77.8%) 2001
# 23           Russians (17.3%) 2001, Other (4.9%) 2001
# 24                                           Language
# 25                                          Ukrainian

# %%
# Replace missing values in columns with the mean of those columns
import pandas as pd
import numpy as np

df.replace("_", np.nan, inplace=True)

print("DataFrame after replacing '_' with NaN:")
print(df.head())

# Select only the numeric columns from DataFrame
numeric_cols = df.select_dtypes(include=[np.number])

# Fill missing values in numeric columns with the mean of the columns
df[numeric_cols.columns] = numeric_cols.fillna(numeric_cols.mean())

print("DataFrame after filling missing values in numeric columns:")
print(df.head())
# Out:
# DataFrame after replacing '_' with NaN:
#                           Demographics of Ukraine  \
# 0  Ukraine population pyramid on 31 December 2023
# 1                                      Population
# 2                                     Growth rate
# 3                                      Birth rate
# 4                                      Death rate
#
#                            Demographics of Ukraine.1
# 0     Ukraine population pyramid on 31 December 2023
# 1  Including Russian occupied territory: 41,130,4...
# 2                −6.6 people/1,000 population (2023)
# 3                 8.6 births/1,000 population (2023)
# 4                15.2 deaths/1,000 population (2023)
# DataFrame after filling missing values in numeric columns:
#                           Demographics of Ukraine  \
# 0  Ukraine population pyramid on 31 December 2023
# 1                                      Population
# 2                                     Growth rate
# 3                                      Birth rate
# 4                                      Death rate
#
#                            Demographics of Ukraine.1
# 0     Ukraine population pyramid on 31 December 2023
# 1  Including Russian occupied territory: 41,130,4...
# 2                −6.6 people/1,000 population (2023)
# 3                 8.6 births/1,000 population (2023)
# 4                15.2 deaths/1,000 population (2023)

# %%
# Replace missing values in columns with the mean of those columns
import pandas as pd
import numpy as np

df.replace("_", np.nan, inplace=True)

print("DataFrame after replacing '_' with NaN:")
print(df.head())

# Select only the numeric columns from DataFrame
numeric_cols = df.select_dtypes(include=[np.number])

# Fill missing values in numeric columns with the mean of the columns
df[numeric_cols.columns] = numeric_cols.fillna(numeric_cols.mean())

print("DataFrame after filling missing values in numeric columns:")
print(df.head())
# Out:
# DataFrame after replacing '_' with NaN:
#                           Demographics of Ukraine  \
# 0  Ukraine population pyramid on 31 December 2023
# 1                                      Population
# 2                                     Growth rate
# 3                                      Birth rate
# 4                                      Death rate
#
#                            Demographics of Ukraine.1
# 0     Ukraine population pyramid on 31 December 2023
# 1  Including Russian occupied territory: 41,130,4...
# 2                −6.6 people/1,000 population (2023)
# 3                 8.6 births/1,000 population (2023)
# 4                15.2 deaths/1,000 population (2023)
# DataFrame after filling missing values in numeric columns:
#                           Demographics of Ukraine  \
# 0  Ukraine population pyramid on 31 December 2023
# 1                                      Population
# 2                                     Growth rate
# 3                                      Birth rate
# 4                                      Death rate
#
#                            Demographics of Ukraine.1
# 0     Ukraine population pyramid on 31 December 2023
# 1  Including Russian occupied territory: 41,130,4...
# 2                −6.6 people/1,000 population (2023)
# 3                 8.6 births/1,000 population (2023)
# 4                15.2 deaths/1,000 population (2023)

# %%
# Example data for birth rates in 2019 for different regions
import pandas as pd

url = "https://en.wikipedia.org/wiki/Demographics_of_Ukraine"

data = {
    "Region": ["Rivne Oblast", "Zakarpattia Oblast", "Volyn Oblast", "Chernivtsi Oblast", "Odesa Oblast"],
    "Birth/2019": [14.5, 14.2, 13.8, 12.7, 11.9]
}
df = pd.DataFrame(data)

# Calculate the average birth rate for Ukraine in 2019
average_birth_rate = df["Birth/2019"].mean()

# Find regions where the birth rate is higher than the national average
regions_above_average = df[df["Birth/2019"] > average_birth_rate]["Region"].tolist()

print("Regions with a birth rate higher than the national average in Ukraine in 2019:", regions_above_average)
# Out:
# Regions with a birth rate higher than the national average in Ukraine in 2019: ['Rivne Oblast', 'Zakarpattia Oblast', 'Volyn Oblast']

# %%
# Data for birth rates in 2014 for diffrent regions
import pandas as pd

url = "https://en.wikipedia.org/wiki/Demographics_of_Ukraine"

data = {
    "Region": ["Rivne Oblast", "Zakarpattia Oblast", "Volyn Oblast", "Chernivtsi Oblast", "Odesa Oblast"],
    "Birth/2019": [14.8, 14.6, 14.11, 12.9, 12.3]
}

df = pd.DataFrame(data)

# Find the region with the highest birth rate in 2014
highest_birth_rate_region = df.lock[df["Birth/2014"].idxmax()]

print(f"The region with the highest birth rate in 2014 is: {highest_birth_rate_region['Region']} with a birth rate of {highest_birth_rate_region['Birth/2014']}.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6992\484554373.py in ?()
#      10
#      11 df = pd.DataFrame(data)
#      12
#      13 # Find the region with the highest birth rate in 2014
# ---> 14 highest_birth_rate_region = df.lock[df["Birth/2014"].idxmax()]
#      15
#      16 print(f"The region with the highest birth rate in 2014 is: {highest_birth_rate_region['Region']} with a birth rate of {highest_birth_rate_region['Birth/2014']}.")
#
# C:\Project\PhythonDataScience\dtsc_modul_2_homework\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lock'
